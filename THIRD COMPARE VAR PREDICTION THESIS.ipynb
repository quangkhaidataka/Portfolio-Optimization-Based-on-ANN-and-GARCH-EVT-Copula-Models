# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import datetime as dt
from arch import arch_model
from tensorflow import keras 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from numpy.random import seed

# %%
garch_clayton = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/garch_clayton.csv').iloc[:,1:]
garch_frank = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/garch_clayton.csv').iloc[:,1:]
garch_gumbel = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/garch_gumbel.csv').iloc[:,1:]
garch_gauss = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/garch_gauss.csv').iloc[:,1:]

#/Users/khai/Desktop/Thesis Asia/generate_copula/garch_clayton.csv


garch_clayton_95 = garch_clayton.quantile(0.025)
garch_clayton_99 = garch_clayton.quantile(0.005)

garch_frank_95 = garch_frank.quantile(0.025)
garch_frank_99 = garch_frank.quantile(0.005)

garch_gumbel_95 = garch_gumbel.quantile(0.025)
garch_gumbel_99 = garch_gumbel.quantile(0.005)

garch_gauss_95 = garch_gauss.quantile(0.025)
garch_gauss_99 = garch_gauss.quantile(0.005)

# %%
ann_garch_clayton = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/ANN_garch_clayton.csv').iloc[:,1:]
ann_garch_frank = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/ANN_garch_frank.csv').iloc[:,1:]
ann_garch_gumbel = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/ANN_garch_gumbel.csv').iloc[:,1:]
ann_garch_gauss = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/ANN_garch_gauss.csv').iloc[:,1:]



ann_garch_clayton_95 = ann_garch_clayton.quantile(0.025)
ann_garch_clayton_99 = ann_garch_clayton.quantile(0.005)

ann_garch_frank_95 = ann_garch_frank.quantile(0.025)
ann_garch_frank_99 = ann_garch_frank.quantile(0.005)

ann_garch_gumbel_95 = ann_garch_gumbel.quantile(0.025)
ann_garch_gumbel_99 = ann_garch_gumbel.quantile(0.005)

ann_garch_gauss_95 = ann_garch_gauss.quantile(0.025)
ann_garch_gauss_99 = ann_garch_gauss.quantile(0.005)

# %%
clayton_gng_garch_ANN = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/clayton_gng_garch_ANN.csv').iloc[:,1:]
frank_gng_garch_ANN = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/frank_gng_garch_ANN.csv').iloc[:,1:]
gumbel_gng_garch_ANN = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/gumbel_gng_garch_ANN.csv').iloc[:,1:]
gauss_gng_garch_ANN = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/gauss_gng_garch_ANN.csv').iloc[:,1:]




clayton_gng_garch_ANN_95 = clayton_gng_garch_ANN.quantile(0.025)
clayton_gng_garch_ANN_99 = clayton_gng_garch_ANN.quantile(0.005)

frank_gng_garch_ANN_95 = frank_gng_garch_ANN.quantile(0.025)
frank_gng_garch_ANN_99 = frank_gng_garch_ANN.quantile(0.005)

gumbel_gng_garch_ANN_95 = gumbel_gng_garch_ANN.quantile(0.025)
gumbel_gng_garch_ANN_99 = gumbel_gng_garch_ANN.quantile(0.005)

gauss_gng_garch_ANN_95 = gauss_gng_garch_ANN.quantile(0.025)
gauss_gng_garch_ANN_99 = gauss_gng_garch_ANN.quantile(0.005)

# %%
clayton_gng_garch = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/clayton_gng_garch.csv').iloc[:,1:]
frank_gng_garch = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/frank_gng_garch.csv').iloc[:,1:]
gumbel_gng_garch = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/gumbel_gng_garch.csv').iloc[:,1:]
gauss_gng_garch = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/gauss_gng_garch.csv').iloc[:,1:]



clayton_gng_garch_95 = clayton_gng_garch.quantile(0.025)
clayton_gng_garch_99 = clayton_gng_garch.quantile(0.005)

frank_gng_garch_95 = frank_gng_garch.quantile(0.025)
frank_gng_garch_99 = frank_gng_garch.quantile(0.005)

gumbel_gng_garch_95 = gumbel_gng_garch.quantile(0.025)
gumbel_gng_garch_99 = gumbel_gng_garch.quantile(0.005)

gauss_gng_garch_95 = gauss_gng_garch.quantile(0.025)
gauss_gng_garch_99 = gauss_gng_garch.quantile(0.005)

# %%
quantile_ANN_95_normal = pd.read_csv('/Users/khai/Desktop/Thesis_Asia_v2/generate_copula/quantile_95_only.csv').iloc[:,1:]

# %%
ann_garch_clayton_95
# Out:
# China       -3.058415
# Hongkong    -4.175738
# Indonesia   -4.228926
# Japan       -3.138717
# Korea       -3.369354
# Singapore   -3.934905
# Name: 0.025, dtype: float64

# %%
stock_lists = ['China','Hongkong','Indonesia','Japan','Korea','Singapore']
print(len(stock_lists))
full_data_train = {}
full_data_test = {}
# Out:
# 6

# %%
direct_link = '/Users/khai/Desktop/Thesis Asia/'
for stock in stock_lists:
    full_data_train[stock] = pd.read_csv(direct_link+f'df_train_{stock}.csv',parse_dates=['Date'],
                                        index_col=['Date'])
    
    full_data_test[stock] = pd.read_csv(direct_link+f'df_test_{stock}.csv',parse_dates=['Date'],
                                        index_col=['Date'])

# %%
for stock in stock_lists:
    full_data_train[stock]['Var95_ANN_GARCH_CLAYTON'] = full_data_train[stock]['garch_mean']+ann_garch_clayton_95[stock]*full_data_train[stock]['ANN_vol']
    full_data_train[stock]['Var99_ANN_GARCH_CLAYTON'] = full_data_train[stock]['garch_mean']+ann_garch_clayton_99[stock]*full_data_train[stock]['ANN_vol']
    
    full_data_train[stock]['Var95_ANN_GARCH_FRANK'] = full_data_train[stock]['garch_mean']+ann_garch_frank_95[stock]*full_data_train[stock]['ANN_vol']
    full_data_train[stock]['Var99_ANN_GARCH_FRANK'] = full_data_train[stock]['garch_mean']+ann_garch_frank_99[stock]*full_data_train[stock]['ANN_vol']
    
    full_data_train[stock]['Var95_ANN_GARCH_GUMBEL'] = full_data_train[stock]['garch_mean']+ann_garch_gumbel_95[stock]*full_data_train[stock]['ANN_vol']
    full_data_train[stock]['Var99_ANN_GARCH_GUMBEL'] = full_data_train[stock]['garch_mean']+ann_garch_gumbel_99[stock]*full_data_train[stock]['ANN_vol']
    
    full_data_train[stock]['Var95_ANN_GARCH_GAUSS'] = full_data_train[stock]['garch_mean']+ann_garch_gauss_95[stock]*full_data_train[stock]['ANN_vol']
    full_data_train[stock]['Var99_ANN_GARCH_GAUSS'] = full_data_train[stock]['garch_mean']+ann_garch_gauss_99[stock]*full_data_train[stock]['ANN_vol']
    
#     full_data_test[stock]['Var95_ANN'] = full_data_test[stock]['garch_mean']+quantile_ANN_95[stock]*full_data_test[stock]['ANN_vol']
#     full_data_test[stock]['Var99_ANN'] = full_data_test[stock]['garch_mean']+quantile_ANN_99[stock]*full_data_test[stock]['ANN_vol']
    
    full_data_train[stock]['Var95_ANN_GNG_CLAYTON'] = full_data_train[stock]['garch_mean']+clayton_gng_garch_ANN_95[stock]*full_data_train[stock]['ANN_vol']
    full_data_train[stock]['Var99_ANN_GNG_CLAYTON'] = full_data_train[stock]['garch_mean']+clayton_gng_garch_ANN_99[stock]*full_data_train[stock]['ANN_vol']
    
    full_data_train[stock]['Var95_ANN_GNG_FRANK'] = full_data_train[stock]['garch_mean']+frank_gng_garch_ANN_95[stock]*full_data_train[stock]['ANN_vol']
    full_data_train[stock]['Var99_ANN_GNG_FRANK'] = full_data_train[stock]['garch_mean']+frank_gng_garch_ANN_99[stock]*full_data_train[stock]['ANN_vol']
    
    full_data_train[stock]['Var95_ANN_GNG_GUMBEL'] = full_data_train[stock]['garch_mean']+gumbel_gng_garch_ANN_95[stock]*full_data_train[stock]['ANN_vol']
    full_data_train[stock]['Var99_ANN_GNG_GUMBEL'] = full_data_train[stock]['garch_mean']+gumbel_gng_garch_ANN_99[stock]*full_data_train[stock]['ANN_vol']
    
    full_data_train[stock]['Var95_ANN_GNG_GAUSS'] = full_data_train[stock]['garch_mean']+gauss_gng_garch_ANN_99[stock]*full_data_train[stock]['ANN_vol']
    full_data_train[stock]['Var99_ANN_GNG_GAUSS'] = full_data_train[stock]['garch_mean']+gauss_gng_garch_ANN_99[stock]*full_data_train[stock]['ANN_vol']
    #clayton_gng_garch_ANN_95
    
    full_data_train[stock]['Var95_GARCH_CLAYTON'] = full_data_train[stock]['garch_mean']+garch_clayton_95[stock]*full_data_train[stock]['forecast_vol_garch']
    full_data_train[stock]['Var99_GARCH_CLAYTON'] = full_data_train[stock]['garch_mean']+garch_clayton_99[stock]*full_data_train[stock]['forecast_vol_garch']
    
    full_data_train[stock]['Var95_GARCH_FRANK'] = full_data_train[stock]['garch_mean']+garch_frank_95[stock]*full_data_train[stock]['forecast_vol_garch']
    full_data_train[stock]['Var99_GARCH_FRANK'] = full_data_train[stock]['garch_mean']+garch_frank_99[stock]*full_data_train[stock]['forecast_vol_garch']
    
    full_data_train[stock]['Var95_GARCH_GUMBEL'] = full_data_train[stock]['garch_mean']+garch_gumbel_95[stock]*full_data_train[stock]['forecast_vol_garch']
    full_data_train[stock]['Var99_GARCH_GUMBEL'] = full_data_train[stock]['garch_mean']+garch_gumbel_99[stock]*full_data_train[stock]['forecast_vol_garch']
    
    full_data_train[stock]['Var95_GARCH_GAUSS'] = full_data_train[stock]['garch_mean']+garch_gauss_95[stock]*full_data_train[stock]['forecast_vol_garch']
    full_data_train[stock]['Var99_GARCH_GAUSS'] = full_data_train[stock]['garch_mean']+garch_gauss_99[stock]*full_data_train[stock]['forecast_vol_garch']
    
    
    
    full_data_train[stock]['Var95_GARCH_GNG_CLAYTON'] = full_data_train[stock]['garch_mean']+clayton_gng_garch_95[stock]*full_data_train[stock]['forecast_vol_garch']
    full_data_train[stock]['Var99_GARCH_GNG_CLAYTON'] = full_data_train[stock]['garch_mean']+clayton_gng_garch_99[stock]*full_data_train[stock]['forecast_vol_garch']
    
    full_data_train[stock]['Var95_GARCH_GNG_FRANK'] = full_data_train[stock]['garch_mean']+frank_gng_garch_95[stock]*full_data_train[stock]['forecast_vol_garch']
    full_data_train[stock]['Var99_GARCH_GNG_FRANK'] = full_data_train[stock]['garch_mean']+frank_gng_garch_99[stock]*full_data_train[stock]['forecast_vol_garch']
    
    full_data_train[stock]['Var95_GARCH_GNG_GUMBEL'] = full_data_train[stock]['garch_mean']+gumbel_gng_garch_95[stock]*full_data_train[stock]['forecast_vol_garch']
    full_data_train[stock]['Var99_GARCH_GNG_GUMBEL'] = full_data_train[stock]['garch_mean']+gumbel_gng_garch_99[stock]*full_data_train[stock]['forecast_vol_garch']
    
    full_data_train[stock]['Var95_GARCH_GNG_GAUSS'] = full_data_train[stock]['garch_mean']+gauss_gng_garch_95[stock]*full_data_train[stock]['forecast_vol_garch']
    full_data_train[stock]['Var99_GARCH_GNG_GAUSS'] = full_data_train[stock]['garch_mean']+gauss_gng_garch_99[stock]*full_data_train[stock]['forecast_vol_garch']

# %%
for stock in stock_lists:
    full_data_test[stock]['Var95_ANN_GARCH_CLAYTON'] = full_data_test[stock]['garch_mean']+ann_garch_clayton_95[stock]*full_data_test[stock]['ANN_vol']
    full_data_test[stock]['Var99_ANN_GARCH_CLAYTON'] = full_data_test[stock]['garch_mean']+ann_garch_clayton_99[stock]*full_data_test[stock]['ANN_vol']
    
    full_data_test[stock]['Var95_ANN_GARCH_FRANK'] = full_data_test[stock]['garch_mean']+ann_garch_frank_95[stock]*full_data_test[stock]['ANN_vol']
    full_data_test[stock]['Var99_ANN_GARCH_FRANK'] = full_data_test[stock]['garch_mean']+ann_garch_frank_99[stock]*full_data_test[stock]['ANN_vol']
    
    full_data_test[stock]['Var95_ANN_GARCH_GUMBEL'] = full_data_test[stock]['garch_mean']+ann_garch_gumbel_95[stock]*full_data_test[stock]['ANN_vol']
    full_data_test[stock]['Var99_ANN_GARCH_GUMBEL'] = full_data_test[stock]['garch_mean']+ann_garch_gumbel_99[stock]*full_data_test[stock]['ANN_vol']
    
    full_data_test[stock]['Var95_ANN_GARCH_GAUSS'] = full_data_test[stock]['garch_mean']+ann_garch_gauss_95[stock]*full_data_test[stock]['ANN_vol']
    full_data_test[stock]['Var99_ANN_GARCH_GAUSS'] = full_data_test[stock]['garch_mean']+ann_garch_gauss_99[stock]*full_data_test[stock]['ANN_vol']
    
#     full_data_test[stock]['Var95_ANN'] = full_data_test[stock]['garch_mean']+quantile_ANN_95[stock]*full_data_test[stock]['ANN_vol']
#     full_data_test[stock]['Var99_ANN'] = full_data_test[stock]['garch_mean']+quantile_ANN_99[stock]*full_data_test[stock]['ANN_vol']
    
    full_data_test[stock]['Var95_ANN_GNG_CLAYTON'] = full_data_test[stock]['garch_mean']+clayton_gng_garch_ANN_95[stock]*full_data_test[stock]['ANN_vol']
    full_data_test[stock]['Var99_ANN_GNG_CLAYTON'] = full_data_test[stock]['garch_mean']+clayton_gng_garch_ANN_99[stock]*full_data_test[stock]['ANN_vol']
    
    full_data_test[stock]['Var95_ANN_GNG_FRANK'] = full_data_test[stock]['garch_mean']+frank_gng_garch_ANN_95[stock]*full_data_test[stock]['ANN_vol']
    full_data_test[stock]['Var99_ANN_GNG_FRANK'] = full_data_test[stock]['garch_mean']+frank_gng_garch_ANN_99[stock]*full_data_test[stock]['ANN_vol']
    
    full_data_test[stock]['Var95_ANN_GNG_GUMBEL'] = full_data_test[stock]['garch_mean']+gumbel_gng_garch_ANN_95[stock]*full_data_test[stock]['ANN_vol']
    full_data_test[stock]['Var99_ANN_GNG_GUMBEL'] = full_data_test[stock]['garch_mean']+gumbel_gng_garch_ANN_99[stock]*full_data_test[stock]['ANN_vol']
    
    full_data_test[stock]['Var95_ANN_GNG_GAUSS'] = full_data_test[stock]['garch_mean']+gauss_gng_garch_ANN_99[stock]*full_data_test[stock]['ANN_vol']
    full_data_test[stock]['Var99_ANN_GNG_GAUSS'] = full_data_test[stock]['garch_mean']+gauss_gng_garch_ANN_99[stock]*full_data_test[stock]['ANN_vol']
    #clayton_gng_garch_ANN_95
    
    full_data_test[stock]['Var95_GARCH_CLAYTON'] = full_data_test[stock]['garch_mean']+garch_clayton_95[stock]*full_data_test[stock]['forecast_vol_garch']
    full_data_test[stock]['Var99_GARCH_CLAYTON'] = full_data_test[stock]['garch_mean']+garch_clayton_99[stock]*full_data_test[stock]['forecast_vol_garch']
    
    full_data_test[stock]['Var95_GARCH_FRANK'] = full_data_test[stock]['garch_mean']+garch_frank_95[stock]*full_data_test[stock]['forecast_vol_garch']
    full_data_test[stock]['Var99_GARCH_FRANK'] = full_data_test[stock]['garch_mean']+garch_frank_99[stock]*full_data_test[stock]['forecast_vol_garch']
    
    full_data_test[stock]['Var95_GARCH_GUMBEL'] = full_data_test[stock]['garch_mean']+garch_gumbel_95[stock]*full_data_test[stock]['forecast_vol_garch']
    full_data_test[stock]['Var99_GARCH_GUMBEL'] = full_data_test[stock]['garch_mean']+garch_gumbel_99[stock]*full_data_test[stock]['forecast_vol_garch']
    
    full_data_test[stock]['Var95_GARCH_GAUSS'] = full_data_test[stock]['garch_mean']+garch_gauss_95[stock]*full_data_test[stock]['forecast_vol_garch']
    full_data_test[stock]['Var99_GARCH_GAUSS'] = full_data_test[stock]['garch_mean']+garch_gauss_99[stock]*full_data_test[stock]['forecast_vol_garch']
    
    
    
    full_data_test[stock]['Var95_GARCH_GNG_CLAYTON'] = full_data_test[stock]['garch_mean']+clayton_gng_garch_95[stock]*full_data_test[stock]['forecast_vol_garch']
    full_data_test[stock]['Var99_GARCH_GNG_CLAYTON'] = full_data_test[stock]['garch_mean']+clayton_gng_garch_99[stock]*full_data_test[stock]['forecast_vol_garch']
    
    full_data_test[stock]['Var95_GARCH_GNG_FRANK'] = full_data_test[stock]['garch_mean']+frank_gng_garch_95[stock]*full_data_test[stock]['forecast_vol_garch']
    full_data_test[stock]['Var99_GARCH_GNG_FRANK'] = full_data_test[stock]['garch_mean']+frank_gng_garch_99[stock]*full_data_test[stock]['forecast_vol_garch']
    
    full_data_test[stock]['Var95_GARCH_GNG_GUMBEL'] = full_data_test[stock]['garch_mean']+gumbel_gng_garch_95[stock]*full_data_test[stock]['forecast_vol_garch']
    full_data_test[stock]['Var99_GARCH_GNG_GUMBEL'] = full_data_test[stock]['garch_mean']+gumbel_gng_garch_99[stock]*full_data_test[stock]['forecast_vol_garch']
    
    full_data_test[stock]['Var95_GARCH_GNG_GAUSS'] = full_data_test[stock]['garch_mean']+gauss_gng_garch_95[stock]*full_data_test[stock]['forecast_vol_garch']
    full_data_test[stock]['Var99_GARCH_GNG_GAUSS'] = full_data_test[stock]['garch_mean']+gauss_gng_garch_99[stock]*full_data_test[stock]['forecast_vol_garch']

# %%
collist = ['Var95_ANN_GARCH_CLAYTON','Var99_ANN_GARCH_CLAYTON','Var95_ANN_GARCH_FRANK','Var99_ANN_GARCH_FRANK',
          'Var95_ANN_GARCH_GUMBEL','Var99_ANN_GARCH_GUMBEL','Var95_ANN_GARCH_GAUSS','Var99_ANN_GARCH_GAUSS',
          'Var95_GARCH_CLAYTON','Var99_GARCH_CLAYTON','Var95_GARCH_FRANK','Var99_GARCH_FRANK','Var95_GARCH_GUMBEL',
          'Var99_GARCH_GUMBEL','Var95_GARCH_GAUSS','Var99_GARCH_GAUSS','Close','Var95_ANN','Var99_ANN',
          'Var95_ANN_GNG_CLAYTON','Var99_ANN_GNG_CLAYTON','Var95_ANN_GNG_FRANK','Var99_ANN_GNG_FRANK',
          'Var95_ANN_GNG_GUMBEL','Var99_ANN_GNG_GUMBEL','Var95_ANN_GNG_GAUSS','Var99_ANN_GNG_GAUSS',
          'Var95_GARCH_GNG_CLAYTON','Var99_GARCH_GNG_CLAYTON','Var95_GARCH_GNG_FRANK','Var99_GARCH_GNG_FRANK',
          'Var95_GARCH_GNG_GUMBEL','Var99_GARCH_GNG_GUMBEL','Var95_GARCH_GNG_GAUSS','Var99_GARCH_GNG_GAUSS']

# %%
for stock in stock_lists:
    full_data_train[stock].to_csv(f'VaR_Prediction_{stock}_train.csv')
    full_data_test[stock].to_csv(f'VaR_Prediction_{stock}_test.csv')

# %%
import sklearn.metrics as metrics
def calculate_metrics(y,yhat):
    mae = metrics.mean_absolute_error(y, yhat)
    mse = metrics.mean_squared_error(y, yhat)
    rmse = np.sqrt(mse) # or mse**(0.5)  
    r2 = metrics.r2_score(y,yhat)
    print("Results of sklearn.metrics:")
    print("MAE:",mae)
    print("MSE:", mse)
    print("RMSE:", rmse)
    print("R-Squared:", r2)

# %% [markdown]
# # CHINA

# %%
full_data_test['China'][['Close','Var95_ANN_GNG_GAUSS']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['China'][['Close','Var95_GARCH_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['China'][['Close','Var95_GARCH_GNG_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_mean = full_data_test['China']

y = list(df_mean['Close'])
yhat_ANN = list(df_mean['Var95_ANN_GNG_GAUSS'])
yhat_Garch = list(df_mean['Var95_GARCH_CLAYTON'])

# %%
calculate_metrics(y,yhat_ANN)
# Out:
# Results of sklearn.metrics:
# MAE: 0.01580139790862637
# MSE: 0.0003273414555447744
# RMSE: 0.018092580124039092
# R-Squared: -3.2743509512715177

# %%
calculate_metrics(y,yhat_Garch)
# Out:
# Results of sklearn.metrics:
# MAE: 0.019485577155527335
# MSE: 0.00046590256738319633
# RMSE: 0.021584776287541095
# R-Squared: -5.0836507211712325

# %% [markdown]
# # KOREA

# %%
full_data_test['Korea'][['Close','Var95_ANN_GNG_GAUSS']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['Korea'][['Close','Var95_GARCH_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # HONGKONG

# %%
full_data_test['Hongkong'][['Close','Var95_ANN_GNG_GAUSS']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['Hongkong'][['Close','Var95_GARCH_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['Hongkong'][['Close','Var95_GARCH_GNG_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # INDONESIA

# %%
full_data_test['Indonesia'][['Close','Var95_ANN_GNG_GAUSS']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['Indonesia'][['Close','Var95_GARCH_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['Indonesia'][['Close','Var95_GARCH_GNG_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # JAPAN

# %%
full_data_test['Japan'][['Close','Var95_ANN_GNG_GAUSS']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['Japan'][['Close','Var95_ANN_GNG_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['Japan'][['Close','Var95_GARCH_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['Japan'][['Close','Var95_GARCH_GNG_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # SINGAPORE

# %%
full_data_test['Singapore'][['Close','Var95_ANN_GNG_GAUSS']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['Singapore'][['Close','Var95_GARCH_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
full_data_test['Singapore'][['Close','Var95_GARCH_GNG_CLAYTON']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
